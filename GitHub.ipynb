# %%
import os
import shutil
from git import Repo

def create_file(path):
    with open(path, 'w') as file:
        file.write('This is a new file.')

def delete_file(path):
    if os.path.exists(path):
        os.remove(path)
    else:
        print("The file does not exist.")

def move_file(source, destination):
    if os.path.exists(source):
        shutil.move(source, destination)
    else:
        print("The file does not exist.")

def copy_file(source, destination):
    if os.path.exists(source):
        shutil.copy2(source, destination)
    else:
        print("The file does not exist.")

def initialize_git_repository():
    repo = Repo.init('.')
    print("Git repository initialized.")

def add_to_git_repository(path):
    repo = Repo('.')
    repo.index.add([path])
    print("File added to Git repository.")

def commit_to_git_repository(message):
    repo = Repo('.')
    repo.index.commit(message)
    print("Changes committed to Git repository.")

def push_to_remote_repository(remote_url):
    repo = Repo('.')
    origin = repo.remote('origin')
    origin.push()
    print("Changes pushed to remote repository.")

# Пример использования функций
new_file_path = 'test.txt'
create_file(new_file_path)

delete_file(new_file_path)

moved_file_path = 'test2.txt'
move_file(new_file_path, moved_file_path)

copied_file_path = 'test3.txt'
copy_file(moved_file_path, copied_file_path)

initialize_git_repository()

add_to_git_repository(copied_file_path)

commit_to_git_repository("Added new file")

remote_repository_url = 'https://github.com/TheXomyak/PythonCourse.git'
push_to_remote_repository(remote_repository_url)

# %%
#!/usr/bin/env python
# coding: utf-8

# In[4]:


# Реализовать прототип консольной программы - проводника, для работы с файлами.
# Создать функции создания, удаления, перемещения, копирования(файла, папки)
# с использованием системы контроля версий git.
# Зарегистрироваться на Github и выгрузить с помощью git программу в созданный репозиторий.
# Прикрепить ссылку на репозиторий
# FileNotFoundError

import os
import pathlib
import shutil
import datetime
from datetime import datetime

curtime = datetime.now().strftime('%d.%m.%Y-%H.%M')
print('\nПривет!\nСегодня ', curtime)
print('\nВы ниходитесь в директории', os.getcwd())
while True:
    Menuchoice = input(
        '\nВыберите пункт меню - что будем делать:\n0 - Создание одной или нескольких папок\n1 - Создание файла\n2 - Удаление папки \n3 - Удаление файла\n4 - Переместить файл\n5 - Переместить папку\n6 - Копирование папки или файла\n7 - Выход из программы \n8 - Сменить текущую директорию')
    match Menuchoice :
        case '0':  # Создание 1 или нескольких папок
            print('\nВы выбрали ре4'
                  'жим "Создание одной или нескольких папок"\n')
            print('\nВы сейчас находитесь в папке', os.getcwd())
            directory = input(
                '\nВведите имя новой папки,\n при создании нескольких папок воспользуйтесь шаблоном dir1/dir2:\n')
            os.makedirs(directory)
            print('\nКоманда по созданию ', directory, 'успешно выполнена!\n')
            print('\nВсе файлы и папки текущей директории:\n', os.listdir())  # Можно попытаться вывести красиво
        case '1':  # Создание файла
            print('\nВы выбрали режим "Создание нового файла"\n')
            print('\nНовый файл будет создан в директории', os.getcwd(), '\n')
            file = input('\nВведите имя нового файла с расширением, пример: новыйфайл.txt\n')
            my_file = open(file, "w+")
            my_file.close()
            print('\nКоманда по созданию ', file, 'успешно выполнена!\n')
            print('\nВсе файлы и папки текущей директории:\n', os.listdir())  # Можно попытаться вывести красиво

        case '2':  # Удаление папки
            print('\nВы выбрали режим "Удаление папки"\n')
            print('\nФайл будет удален из директории', os.getcwd(), '\n')
            directory2 = input('\nВведите имя удаляемой директории\n')
            if os.path.isdir(directory2) == False:
                print('Это не папка! Удалить не возможно')
            else:
                os.rmdir(directory2)
                print('\nКоманда по удалению ', directory2, 'успешно выполнена!\n')
                print('\nВсе файлы и папки текущей директории:\n', os.listdir())  # Можно попытаться вывести красиво
        case '3':  # Удаление файла
            print('\nВы выбрали режим "Удаление файла"\n')
            print('\nФайл будет удален из директории', os.getcwd(), '\n')
            file3 = input('\nВведите имя удаляемого файла с расширением, пример: новыйфайл.txt\n')
            if os.path.isfile(file3) == False:
                print('Это не файл! Удалить не возможно')
            else:
                os.remove(file3)
                print('\nКоманда по удалению ', fil4e3, 'успешно выполнена!\n')
                print('\nВсе файлы и папки текущей директории:\n', os.listdir())  # Можно попытаться вывести красиво
        case '4':  # Переместить файл
            print('\nВы выбрали режим "Перемещение файла"\n')
            print('\nФайл будет перемещен из', os.getcwd(), '\n')
            directory4 = input('\nВведите имя папки, куда переместить\n')
            # directory5='/'+directory4
            if os.path.isdir(directory4) == False:
                print('Это не папка! Сюда переместить не возможно')
            else:
                file4 = input('\nВведите имя файла, который хотите переместить\n')
                if os.path.isfile(file4) == False:
                    print('Это не файл! Переместить не возможно')
                else:
                    try:
                        shutil.move(file4, directory4)
                        print('\nКоманда по перемещению ', file4, 'в', directory4, 'успешно выполнена!\n')
                        print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory4))
                    except FileNotFoundError:
                        print('\nКоманда по перемещению ', file4, 'в', directory4, 'успешно выполнена!\n')
                        print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory4))
        case '5':  # Переместить папку
            print('\nВы выбрали режим "Перемещение папки"\n')
            print('\nПапка будет перемещен из', os.getcwd(), '\n')
            directory5 = input('\nВведите имя папки, куда переместить\n')
            # directory5='/'+directory4
            if os.path.isdir(directory5) == False:
                print('Это не папка! Сюда переместить не возможно')
            else:
                objdirectory5 = input('\nВведите имя папки, которую хотите переместить\n')
                if os.path.isdir(objdirectory5) == False:
                    print('Это не папка! Переместить не возможно')
                else:
                    try:
                        shutil.move(objdirectory5, directory5)
                        print('\nКоманда по перемещению ', objdirectory5, 'в', directory5, 'успешно выполнена!\n')
                        print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory5))
                    except FileNotFoundError:
                        print('\nКоманда по перемещению ', objdirectory5, 'в', directory5, 'успешно выполнена!\n')
                        print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory5))
        case '6':  # Копирование файла или папки (вместе с ее содержимым)
            print('\nВы выбрали режим "Копирование файла или папки (вместе с ее содержимым)"\n')
            print('\nФайл/Папка будет скопирована из', os.getcwd(), '\n')
            object6 = input('\nВведите имя файла/папки, которую хотите скопировать\n')
            directory6 = input('\nВведите имя папки, куда скопировать\n')
            if os.path.isdir(directory6) == False:
                print('Это не папка! Сюда переместить не возможно')
            elif os.path.isdir(object6) == True and os.path.isdir(directory6) == True:
                shutil.copy(object6, directory6)
                print('\nКоманда по копированию ', object6, 'в', directory6, 'выполнена!\n')
                print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory6))
            elif os.path.isfile(object6) == True and os.path.isdir(directory6) == True:
                shutil.copy2(object6, directory6)
                print('\nКоманда по копированию ', object6, 'в', directory6, 'выполнена!\n')
                print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory6))
            else:
                print('Что-то Вы написали не так!')

        case '7':  # DONEExit
            print('\nВы выбрали пункт закрытия программы\n')
            print('До скорой встречи!')
            break
        case '8':
            print('\nТекущая директория', os.getcwd(), '\n')
            directory8=input('Введите новую текущую директорию')
            os.chdir(directory8)
            print('Текущая директория изменена на ', directory8)
        case _:
            print('\n\33[31mНет такого пункта меню!\33[m\n Попробуйте снова.\n')

# %%
import sys
print(sys.version)

# %%
import os
import pathlib
import shutil
import datetime
from datetime import datetime
#from git import Repo


# Основная функция меню
curtime = datetime.now().strftime('%d.%m.%Y-%H.%M')
print('\nПривет!\nСегодня ', curtime)
print('\nВы ниходитесь в директории', os.getcwd())
def main_menu():
    while True:
        print("1. Создание одной или нескольких папок")
        print("2. Создание файла")
        print("3. Удаление папки")
        print("4. Удаление файла")
        print("5. Переместить файл")
        print("6. Переместить папку")
        print("7. Копирование папки или файла")
        print("8. Сменить текущую директорию")
        print("9. Выберите файл с программой для выгрузки на Github")
        print("0. Выход")
        
        choice = input("Выберите операцию: ")

        if choice == "1": # Создание папки или папок
            print('Рабочая папка', os.getcwd())
            directory_new = input('Введите имя новой папки, при создании нескольких папок воспользуйтесь шаблоном Имяпапки1/Имяпапки2:')
            os.makedirs(directory_new)
            print('Команда по созданию ', directory, 'успешно выполнена!')
        elif choice == "2":
            print('Новый файл будет создан в папке', os.getcwd())
            filename = input('Введите имя создаваемого файла с расширением, пример: имяфайла.txt')
            file = open(filename, "w+")
            file.close()
        elif choice == "3":
            print('Удаляем папку из рабочего каталога', os.getcwd(), '\n')
            directory2 = input('Ввводим имя папки для удаления')
            if os.path.isdir(directory2) == False:
                print('Это удалить нельзя')
            else:
                os.rmdir(directory2)
        elif choice == "4":
            print('Удаляем файл в папке', os.getcwd())
            file_delete = input('Вводим имя файла с расширением, пример: удаляемыйфайл.txt')
            if os.path.isfile(file_delete) == False:
                print('Это не то! Удалить не возможно')
            else:
                os.remove(file3)
        elif choice == "5":
            print('Файл будет перемещен из', os.getcwd())
            directory_transfer = input('Укажите папку в которую перемещаем файл')
            if os.path.isdir(directory_transfer) == False:
                print('Сюда переместить нельзя')
            else:
                file_transfer = input('Напишите имя файла который перемещаем')
                if os.path.isfile(file_transfer) == False:
                    print('Это не то! Переместить не возможно')
                else:
                    try:
                        shutil.move(file_transfer, directory_transfer)
                        print('Файл перемещен в целевую папку')
                    except FileNotFoundError:
                        print('\nКоманда по перемещению ', file4, 'в', directory4, 'успешно выполнена!\n')
                        print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory4))
        elif choice == "6":
            print('Папка будет перемещен из', os.getcwd())
            directory_to_move = input('Напишите имя папку куда перемещаем')
            if os.path.isdir(directory_to_move) == False:
                print('Сюда переместить нельзя')
            else:
                directory_for_move = input('Напишите имя папки для перемещения')
                if os.path.isdir(directory_for_move) == False:
                    print('Сюда переместить нельзя')
                else:
                    try:
                        shutil.move(directory_for_move, directory_to_move)
                        print('\nКоманда по перемещению ', objdirectory5, 'в', directory5, 'успешно выполнена!\n')
                        print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory5))
                    except FileNotFoundError:
                        print('\nКоманда по перемещению ', objdirectory5, 'в', directory5, 'успешно выполнена!\n')
                        print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory5))
        elif choice == "7":
            print('\nФайл/Папка будет скопирована из', os.getcwd(), '\n')
            print('\nВы выбрали режим "Копирование файла или папки (вместе с ее содержимым)"\n')
            print('\nФайл/Папка будет скопирована из', os.getcwd(), '\n')
            object6 = input('\nВведите имя файла/папки, которую хотите скопировать\n')
            directory6 = input('\nВведите имя папки, куда скопировать\n')
            if os.path.isdir(directory6) == False:
                print('Это не папка! Сюда переместить не возможно')
            elif os.path.isdir(object6) == True and os.path.isdir(directory6) == True:
                shutil.copy(object6, directory6)
                print('\nКоманда по копированию ', object6, 'в', directory6, 'выполнена!\n')
                print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory6))
            elif os.path.isfile(object6) == True and os.path.isdir(directory6) == True:
                shutil.copy2(object6, directory6)
                print('\nКоманда по копированию ', object6, 'в', directory6, 'выполнена!\n')
                print('\nВсе файлы и папки выбранной директории:\n', os.listdir(directory6))
            else:
                print('Что-то Вы написали не так!')
        elif choice == "8":
            print('Вы сейчас в папке', os.getcwd())
            directory_change=input('Напишите имя папки которая станет текущей')
            os.chdir(directory_change)
            print('Текущая директория изменена на ', directory_change)
        elif choice == "9":
            print('\nТекущая директория', os.getcwd(), '\n')
        elif choice == "0":
            print('\nВы выбрали пункт закрытия программы\n')
            print('До скорой встречи!')
            break
        else:
            print("Некорректный выбор. Попробуйте снова.")

if __name__ == "__main__":
    main_menu()
